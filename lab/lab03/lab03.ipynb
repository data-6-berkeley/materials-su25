# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab03.ipynb")

# %% [markdown]
# <img src="data6.png" style="width: 15%; float: right; padding: 1%; margin-right: 2%;"/>
#
# # Lab 3 – Functions Practice
#
# ## Data 6, Summer 2025

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />

# %%
# Import necessary packages
from datascience import *
import numpy as np

# %% [markdown]
# <hr style="border: 1px solid #fdb515;" />
#
# The table `survey_responses` contains responses from students along with the amount of time (in minutes) they took to complete the survey.

# %%
survey_responses = Table.read_table("survey_responses.csv")
survey_responses

# %% [markdown]
# <br/>
#
# ---
#
# ## Question 1: Fun with Functions!
#
# Let's do some survey analysis! Implement a function that takes in a Table `table` and an integer `threshold`, and returns a Table with all the survey responses that spent longer or equal to `lower_threshold` minutes and less than `upper_threshold` to fill out the survey.

# %%
def filter_time(table, lower_threshold, upper_threshold):
    """
    Takes in a table and returns all the rows that spent longer than threshold minutes.

    Inputs:
    table: a Table that contains a column 'Time Taken (minutes)'
    threshold: an integer

    Returns:
    a Table with all the survey responses that spent longer than threshold minutes
    """

    ...

# %%
grader.check("q1")

# %%
between_ten_and_twenty = filter_time(survey_responses, 10, 20)
between_ten_and_twenty

# %% [markdown]
# <br/>
#
# ---
#
# ## Question 2: String Manipulation
#
# Jedi wants one string of all of the `Student Name`s. Write a function that takes in a table and a column name, and concatenates together all of the names, separated by a parameter `separator`.

# %%
def concatenate_names(tbl, separator, col_name):
    """
    Inputs:
    tbl: a Table
    separator: a string
    col_name: a string

    Returns:
    a string with all the names concatenated together

    """
    ...

# Now call the function with the survey_responses table, a space as the separator, and "Student Name" as the column name
concatenated_survey_names = ...
concatenated_survey_names

# %%
grader.check("q2")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Reflect:** What information did we lose when concatenating all the survey names together into one string?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ---
#
# ## Question 3: Functions within functions.
#
# Sometimes, we'll have helper functions to perform some subroutine for us so we can abstract away more low-level tasks. Finish this implementation of a function that adds a new column, `Updated Values`, to a table that doubles, then squares all the values inside of column `col`.

# %%
def add_doubled_squared_col(tbl, col):
    """Adds a new column called Updated_Values to tbl that doubles, then squares the values in col"""
    ...


survey_with_modified_times = add_doubled_squared_col(survey_responses, "Time Taken (minutes)")
survey_with_modified_times

# %%
grader.check("q3")

# %% [markdown]
# Now, here is the re-implementation of the helper function without taking in any parameters.

# %%
def add_doubled_squared_col(tbl, col):
    """Adds a new column called Updated_Values to tbl that doubles, then squares the values in col"""
    def double_squared():
        """Takes in nothing and returns a new array with the values doubled, then squared"""
        return (tbl.column(col) * 2) ** 2
    return tbl.with_column("Updated Values", double_squared())


survey_responses.column("Student Name")

# %%
survey_with_modified_times = add_doubled_squared_col(survey_responses, "Time Taken (minutes)")
survey_with_modified_times

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ---
#
# ## Question 4: Understanding Error Messages
#
# For each of the following buggy implementations, write what the issue is and fix the implementation.

# %%
def triple(x):
    """Return the value of x, tripled"""
    x * 3

# %%
a = 5
triple(a) #We expect this to evaluate to 15

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ---

# %%
def quadruple(x):
    """Return the value of x, quadrupled"""
    4 = x * 4
    return 4

quadruple(4)

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ---

# %%
def quintuple(x):
    x = x * 5
    return x

quintuple(4)
print(x) # Jedi expects x to be 20

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <hr>
#
# ## Done! 😇

# %% [markdown]
# ## Pets of Data 6
# Enjoy the grass and shade during this Summer heat! Congrats on finishing Lab 3.
#
# <img src="paulina.jpg" width="50%" alt="Two cute sleepy cats on a floral cushion"/>

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False)
